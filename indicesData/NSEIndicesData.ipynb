# %%
import pandas as pd
# Source of data https://www.nseindia.com/products-services/indices-nifty200-index
fileList = ['NIFTY_100', 'NIFTY_200', 'NIFTY_50', 'NIFTY_500', 'NIFTY_500MULTICAP502525', 'NIFTY_LARGEMIDCAP250', 'NIFTY_MICROCAP250', 'NIFTY_MIDCAP100', 'NIFTY_MIDCAP150', 'NIFTY_MIDCAP50', 'NIFTY_MIDSMALLCAP400', 'NIFTY_NEXT50', 'NIFTY_SMALLCAP100', 'NIFTY_SMALLCAP250', 'NIFTY_SMALLCAP50', 'NIFTY_TOTALMARKET']
listing = [ 'Industry', 'ISIN Code', 'Series', 'Company Name']

for item in fileList:
    df = pd.read_csv(item)
    df[item] = item
    df[['Symbol', item]].to_csv(item + ".csv", index=False)

for item in listing:
    df = pd.read_csv(item)
    df[['Symbol', item]].to_csv(item + ".csv", index=False)

# %%
from symbol import if_stmt
import pandas as pd
fileList = [ 'NIFTY_100', 'NIFTY_200', 'NIFTY_50', 'NIFTY_500', 'NIFTY_500MULTICAP502525', 'NIFTY_LARGEMIDCAP250', 'NIFTY_MICROCAP250', 'NIFTY_MIDCAP100', 'NIFTY_MIDCAP150', 'NIFTY_MIDCAP50', 'NIFTY_MIDSMALLCAP400', 'NIFTY_NEXT50', 'NIFTY_SMALLCAP100', 'NIFTY_SMALLCAP250', 'NIFTY_SMALLCAP50', 'NIFTY_TOTALMARKET']
df = pd.DataFrame(columns=fileList)

allData = dict()
for name, symbol in pd.read_csv('NIFTY_TOTALMARKET.csv')['Symbol'].iteritems():
    allData[symbol] = {
    'Symbol' : '',
    'Industry' : '',
    'ISIN Code' : '',
    'Series' : '',
    'Company Name' : '',
    'NIFTY_100' : '',
    'NIFTY_200' : '',
    'NIFTY_50' : '',
    'NIFTY_500' : '',
    'NIFTY_500MULTICAP502525' : '',
    'NIFTY_LARGEMIDCAP250' : '',
    'NIFTY_MICROCAP250' : '',
    'NIFTY_MIDCAP100' : '',
    'NIFTY_MIDCAP150' : '',
    'NIFTY_MIDCAP50' : '',
    'NIFTY_MIDSMALLCAP400' : '',
    'NIFTY_NEXT50' : '',
    'NIFTY_SMALLCAP100' : '',
    'NIFTY_SMALLCAP250' : '',
    'NIFTY_SMALLCAP50' : '',
    'NIFTY_TOTALMARKET' : ''
    }
    allData[symbol]['Symbol'] = symbol

for item in fileList:
    df = pd.read_csv(item + ".csv")    
    df = df.reset_index()
    for x, y in zip(df['Symbol'], df[item]):
        allData[x][y] = y

# %%
listing = [ 'Industry', 'ISIN Code', 'Series', 'Company Name']

industry = pd.read_csv("Industry.csv")
for x, y in zip(industry['Symbol'], industry['Industry']):
    allData[x]['Industry'] = y

ISIN = pd.read_csv("ISIN Code.csv")
for x, y in zip(ISIN['Symbol'], ISIN['ISIN Code']):
    allData[x]['ISIN Code'] = y

Series = pd.read_csv("Series.csv")
for x, y in zip(Series['Symbol'], Series['Series']):
    allData[x]['Series'] = y

Company = pd.read_csv("Company Name.csv")
for x, y in zip(Company['Symbol'], Company['Company Name']):
    allData[x]['Company Name'] = y

print(allData)

# %%
listOfData = []
for item in allData:
    listOfData.append(allData[item])
#print(listOfData)
df = pd.DataFrame.from_records(listOfData).fillna(0)
display(df)
df.to_csv("IndiceData.csv")
# Out:
#          Symbol                    Industry     ISIN Code Series  \
# 0       3MINDIA                 Diversified  INE470A01017     EQ
# 1           ABB               Capital Goods  INE117A01022     EQ
# 2           ACC      Construction Materials  INE012A01025     EQ
# 3      ADFFOODS  Fast Moving Consumer Goods  INE982B01019     EQ
# 4           AGI               Capital Goods  INE415A01038     EQ
# ..          ...                         ...           ...    ...
# 746  ZENSARTECH      Information Technology  INE520A01027     EQ
# 747      ZOMATO           Consumer Services  INE758T01015     EQ
# 748   ZYDUSLIFE                  Healthcare  INE010B01027     EQ
# 749   ZYDUSWELL  Fast Moving Consumer Goods  INE768C01010     EQ
# 750      ECLERX                    Services  INE738I01010     EQ
#
#                 Company Name  NIFTY_100  NIFTY_200 NIFTY_50  NIFTY_500  \
# 0              3M India Ltd.                                 NIFTY_500
# 1             ABB India Ltd.             NIFTY_200           NIFTY_500
# 2                   ACC Ltd.  NIFTY_100  NIFTY_200           NIFTY_500
# 3             ADF Foods Ltd.
# 4          AGI Greenpac Ltd.
# ..                       ...        ...        ...      ...        ...
# 746  Zensar Technolgies Ltd.                                 NIFTY_500
# 747              Zomato Ltd.  NIFTY_100  NIFTY_200           NIFTY_500
# 748  Zydus Lifesciences Ltd.  NIFTY_100  NIFTY_200           NIFTY_500
# 749      Zydus Wellness Ltd.                                 NIFTY_500
# 750     eClerx Services Ltd.                                 NIFTY_500
#
#      NIFTY_500MULTICAP502525  ...  NIFTY_MICROCAP250  NIFTY_MIDCAP100  \
# 0    NIFTY_500MULTICAP502525  ...
# 1    NIFTY_500MULTICAP502525  ...                     NIFTY_MIDCAP100
# 2    NIFTY_500MULTICAP502525  ...
# 3                             ...  NIFTY_MICROCAP250
# 4                             ...  NIFTY_MICROCAP250
# ..                       ...  ...                ...              ...
# 746  NIFTY_500MULTICAP502525  ...
# 747  NIFTY_500MULTICAP502525  ...
# 748  NIFTY_500MULTICAP502525  ...
# 749  NIFTY_500MULTICAP502525  ...
# 750  NIFTY_500MULTICAP502525  ...
#
#      NIFTY_MIDCAP150  NIFTY_MIDCAP50  NIFTY_MIDSMALLCAP400  NIFTY_NEXT50  \
# 0    NIFTY_MIDCAP150                  NIFTY_MIDSMALLCAP400
# 1    NIFTY_MIDCAP150  NIFTY_MIDCAP50  NIFTY_MIDSMALLCAP400
# 2                                                           NIFTY_NEXT50
# 3
# 4
# ..               ...             ...                   ...           ...
# 746                                   NIFTY_MIDSMALLCAP400
# 747                                                         NIFTY_NEXT50
# 748                                                         NIFTY_NEXT50
# 749                                   NIFTY_MIDSMALLCAP400
# 750                                   NIFTY_MIDSMALLCAP400
#
#      NIFTY_SMALLCAP100  NIFTY_SMALLCAP250  NIFTY_SMALLCAP50  NIFTY_TOTALMARKET
# 0                                                            NIFTY_TOTALMARKET
# 1                                                            NIFTY_TOTALMARKET
# 2                                                            NIFTY_TOTALMARKET
# 3                                                            NIFTY_TOTALMARKET
# 4                                                            NIFTY_TOTALMARKET
# ..                 ...                ...               ...                ...
# 746  NIFTY_SMALLCAP100  NIFTY_SMALLCAP250  NIFTY_SMALLCAP50  NIFTY_TOTALMARKET
# 747                                                          NIFTY_TOTALMARKET
# 748                                                          NIFTY_TOTALMARKET
# 749                     NIFTY_SMALLCAP250                    NIFTY_TOTALMARKET
# 750                     NIFTY_SMALLCAP250                    NIFTY_TOTALMARKET
#
# [751 rows x 21 columns]

# %%
df = pd.read_csv("IndiceData.csv")
#display(df)
